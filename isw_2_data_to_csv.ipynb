# %%
import pandas as pd
import glob
from datetime import datetime

from bs4 import BeautifulSoup

# %%
INPUT_PATH = "data/isw/raw"
OUTPUT_PATH = "data/isw/reports.csv"
BASE_URL = "https://www.understandingwar.org"

# %%
reports = glob.glob(f"{INPUT_PATH}/*.html")

# %%
data = []

for file in reports:
    file_name_parts = file.split("/")[-1].split("__")
    date = datetime.strptime(file_name_parts[0], "%d_%m_%Y")
    
    with open(file, "r") as cfile:
        html = BeautifulSoup(cfile.read())
        page_title = html.head.find("title").text
        url = BASE_URL + html.head.find("link", attrs={"rel": "canonical"}, href=True).attrs["href"]
        
        content_title = html.body.find("h1", attrs={"id": "page-title"}).text
        content_html = html.body.find("div", attrs={"class": "field-type-text-with-summary"})
        
        d = {
            "date": date,
            "url": url,
            "page_title": page_title,
            "content_title": content_title,
            "content_html": content_html
        }
        
        data.append(d)

# %%
df = pd.DataFrame.from_dict(data).sort_values(by=['date'])

# %%
df.head(10)
# Out:
#           date                                                url  \
# 138 2022-02-25  https://www.understandingwar.org/backgrounder/...
# 126 2022-02-26  https://www.understandingwar.org/backgrounder/...
# 119 2022-02-27  https://www.understandingwar.org/backgrounder/...
# 11  2022-02-28  https://www.understandingwar.org/backgrounder/...
# 227 2022-03-01  https://www.understandingwar.org/backgrounder/...
# 199 2022-03-02  https://www.understandingwar.org/backgrounder/...
# 213 2022-03-03  https://www.understandingwar.org/backgrounder/...
# 195 2022-03-04  https://www.understandingwar.org/backgrounder/...
# 179 2022-03-05  https://www.understandingwar.org/backgrounder/...
# 160 2022-03-06  https://www.understandingwar.org/backgrounder/...
#
#                                             page_title  \
# 138  Russia-Ukraine Warning Update: Russian Offensi...
# 126  Russia-Ukraine Warning Update: Russian Offensi...
# 119  Russia-Ukraine Warning Update: Russian Offensi...
# 11   Russian Offensive Campaign Assessment, Februar...
# 227  Russian Offensive Campaign Assessment, March 1...
# 199  Russian Offensive Campaign Assessment, March 2...
# 213  Russian Offensive Campaign Assessment, March 3...
# 195  Russian Offensive Campaign Assessment, March 4...
# 179  Russian Offensive Campaign Assessment, March 5...
# 160  Russian Offensive Campaign Assessment, March 6...
#
#                                          content_title  \
# 138  Russia-Ukraine Warning Update: Russian Offensi...
# 126  Russia-Ukraine Warning Update: Russian Offensi...
# 119  Russia-Ukraine Warning Update: Russian Offensi...
# 11   Russian Offensive Campaign Assessment, Februar...
# 227     Russian Offensive Campaign Assessment, March 1
# 199     Russian Offensive Campaign Assessment, March 2
# 213     Russian Offensive Campaign Assessment, March 3
# 195     Russian Offensive Campaign Assessment, March 4
# 179     Russian Offensive Campaign Assessment, March 5
# 160     Russian Offensive Campaign Assessment, March 6
#
#                                           content_html
# 138  [[[ , <p align="center" style="text-align: lef...
# 126  [[[ , <p align="center" style="text-align: lef...
# 119  [[[ , <p style="text-align: left;"><strong><sp...
# 11   [[[ , <p align="center" style="text-align: lef...
# 227  [[[ , <p align="center" style="text-align: lef...
# 199  [[[ , <p align="center" style="text-align: lef...
# 213  [[[ , <p align="center" style="text-align: lef...
# 195  [[[ , <p align="center" style="text-align: lef...
# 179  [[[ , <p align="center" style="text-align: lef...
# 160  [[[ , <p align="center" style="text-align: lef...

# %%
df.to_csv(f"{OUTPUT_PATH}", sep=";", index=False)
